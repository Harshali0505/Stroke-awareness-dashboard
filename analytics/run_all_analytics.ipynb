# %% [markdown]
# # Analytics JSON Generator\n\nThis notebook regenerates all dashboard JSON files into `public/analytics` from the CSV in `analytics/data`.

# %%
from analytics.run_all import main
main()
